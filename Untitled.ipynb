# %%
# Αν χρειαστεί, τρέξτε στο terminal: pip install tsb-uad
try:
    from tsb_uad.datasets import list_datasets, load_dataset
    print("✅ TSB-UAD imported successfully!")
except ImportError:
    print("❌ TSB-UAD not installed. Run: pip install tsb-uad")
# Out:
# ❌ TSB-UAD not installed. Run: pip install tsb-uad
