# %% [markdown]
# # Gilbert-Elliott Robustness Experiment (Colab Runner)
#
# Αυτό το notebook είναι ρυθμισμένο για να τρέχει το βασικό πείραμα αξιολόγησης `run_ge_experiment.py` κατευθείαν μέσα από το Google Drive σου, εκμεταλλευόμενο τους πόρους του Google Colab.

# %% [markdown]
# ### 1. Σύνδεση με το Google Drive
# Τρέξε το παρακάτω κελί για να δώσεις πρόσβαση στο Colab να διαβάσει και να γράψει στο Google Drive σου.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 2. Μετάβαση στο φάκελο του Project
# Εδώ ορίζουμε που ακριβώς βρίσκεται ο φάκελος της διπλωματικής σου μέσα στο Drive.
# **ΠΡΟΣΟΧΗ**: Αν έχεις αλλάξει το όνομα του φακέλου ή τον έχεις βάλει μέσα σε άλλο φάκελο, άλλαξε το path παρακάτω:

# %%
import os

# Το σωστό path για συγχρονισμένους φακέλους από υπολογιστή
PROJECT_PATH = '/content/drive/Othercomputers/Ο φορητός υπολογιστής μου/thesis_timeseries'

os.chdir(PROJECT_PATH)
print("Current working directory:", os.getcwd())

# Έλεγχος ότι βρισκόμαστε στο σωστό μέρος
if os.path.exists('src/experiments/corruption/run_ge_experiment.py'):
    print("✅ Το Path είναι σωστό! Το αρχείο experiment βρέθηκε.")
else:
    print("❌ Το αρχείο experiment ΔΕΝ βρέθηκε. Έλεγξε το PROJECT_PATH.")
# Out:
# Current working directory: /content/drive/Othercomputers/Ο φορητός υπολογιστής μου/thesis_timeseries
# ✅ Το Path είναι σωστό! Το αρχείο experiment βρέθηκε.

# %% [markdown]
# ### 3. Εγκατάσταση Εξαρτήσεων (Dependencies)
# Επειδή το Colab ξεκινάει με ένα καθαρό περιβάλλον Python, πρέπει να εγκαταστήσουμε ό,τι λείπει (π.χ. το TSB-UAD).

# %%
# !pip install -r requirements.txt

# Εγκατάσταση του TSB-UAD αν δεν είναι ήδη εγκατεστημένο
import sys
if not os.path.exists('TSB-UAD/TSB_UAD/__init__.py'):
    print("TSB-UAD module needed, applying hotfix for Colab...")
    # Προσθέτουμε προσωρινά το φάκελο TSB-UAD στο python path
    sys.path.append(os.path.join(os.getcwd(), 'TSB-UAD'))
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %% [markdown]
# ### 4. Εκτέλεση του Πειράματος 🎉
# Τρέχουμε το κεντρικό script. Το `--workers 2` ορίζεται επειδή τα δωρεάν Colab instances έχουν συνήθως μόνο 2 cores.
# Το autosave (checkpointing) δουλεύει κανονικά! Αν κλείσει το Colab (ή τελειώσει το session), την επόμενη φορά θα συνεχίσει από εκεί που έμεινε.

# %%
# !python src/experiments/corruption/run_ge_experiment.py --workers 400
# Out:
# /content/drive/Othercomputers/Ο φορητός υπολογιστής μου/thesis_timeseries/src/experiments/corruption/run_ge_experiment.py:212: DtypeWarning: Columns (2,6,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_check = pd.read_csv(checkpoint_file)
# Loaded 76340 jobs from checkpoint.
# Total Jobs to run: 24608
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/stattools.py:702: RuntimeWarning: invalid value encountered in divide
#   acf = avf[: nlags + 1] / avf[0]
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/stattools.py:702: RuntimeWarning: invalid value encountered in divide
#   acf = avf[: nlags + 1] / avf[0]
# Process ForkProcess-400:
# Process ForkProcess-57:
# Process ForkProcess-216:
# Process ForkProcess-282:
# Process ForkProcess-38:
# Process ForkProcess-105:
# Process ForkProcess-252:
# Process ForkProcess-228:
# Process ForkProcess-70:
# Process ForkProcess-60:
# Process ForkProcess-160:
# Process ForkProcess-227:
# Process ForkProcess-173:
# Process ForkProcess-305:
# Process ForkProcess-255:
# Process ForkProcess-263:
# Process ForkProcess-302:
# Process ForkProcess-25:
# Process ForkProcess-137:
# Process ForkProcess-343:
# Process ForkProcess-37:
# Process ForkProcess-220:
# Process ForkProcess-312:
# Process ForkProcess-124:
# Process ForkProcess-300:
# Process ForkProcess-69:
# Process ForkProcess-28:
# Process ForkProcess-96:
# Process ForkProcess-205:
# Process ForkProcess-78:
# Process ForkProcess-41:
# Process ForkProcess-129:
# Process ForkProcess-225:
# Process ForkProcess-388:
# Process ForkProcess-277:
# Process ForkProcess-118:
# Process ForkProcess-155:
# Process ForkProcess-237:
# Process ForkProcess-217:
# Process ForkProcess-93:
# Process ForkProcess-301:
# Process ForkProcess-169:
# Process ForkProcess-392:
# Process ForkProcess-36:
# Process ForkProcess-31:
# Process ForkProcess-338:
# Process ForkProcess-62:
# Process ForkProcess-79:
# Process ForkProcess-52:
# Process ForkProcess-17:
# Process ForkProcess-353:
# Process ForkProcess-221:
# Process ForkProcess-30:
# Process ForkProcess-245:
# Process ForkProcess-43:
# Process ForkProcess-56:
# Process ForkProcess-222:
# Process ForkProcess-253:
# Process ForkProcess-247:
# Process ForkProcess-35:
# Process ForkProcess-84:
# Process ForkProcess-9:
# Process ForkProcess-324:
# Process ForkProcess-71:
# Process ForkProcess-321:
# Process ForkProcess-348:
# Process ForkProcess-207:
# Process ForkProcess-383:
# Process ForkProcess-258:
# Process ForkProcess-21:
# Process ForkProcess-389:
# Process ForkProcess-33:
# Process ForkProcess-356:
# Process ForkProcess-53:
# Process ForkProcess-382:
# Process ForkProcess-385:
# Process ForkProcess-202:
# Process ForkProcess-199:
# Process ForkProcess-143:
# Process ForkProcess-352:
# Process ForkProcess-218:
# Process ForkProcess-241:
# Process ForkProcess-387:
# Process ForkProcess-369:
# Process ForkProcess-167:
# Process ForkProcess-319:
# Process ForkProcess-295:
# Process ForkProcess-380:
# Process ForkProcess-355:
# Process ForkProcess-233:
# Process ForkProcess-375:
# Process ForkProcess-144:
# Process ForkProcess-180:
# Process ForkProcess-204:
# Process ForkProcess-262:
# Process ForkProcess-379:
# Process ForkProcess-134:
# Process ForkProcess-209:
# Process ForkProcess-390:
# Process ForkProcess-20:
# Process ForkProcess-197:
# Process ForkProcess-192:
# Process ForkProcess-326:
# Process ForkProcess-359:
# Process ForkProcess-181:
# Process ForkProcess-97:
# Process ForkProcess-364:
# Process ForkProcess-367:
# Process ForkProcess-195:
# Process ForkProcess-201:
# Process ForkProcess-350:
# Process ForkProcess-264:
# Process ForkProcess-88:
# Process ForkProcess-115:
# Process ForkProcess-276:
# Process ForkProcess-145:
# Process ForkProcess-298:
# Process ForkProcess-328:
# Process ForkProcess-152:
# Process ForkProcess-372:
# Process ForkProcess-294:
# Process ForkProcess-361:
# Process ForkProcess-330:
# Process ForkProcess-147:
# Process ForkProcess-184:
# Process ForkProcess-296:
# Process ForkProcess-177:
# Process ForkProcess-186:
# Process ForkProcess-311:
# Process ForkProcess-3:
# Process ForkProcess-213:
# Process ForkProcess-190:
# Process ForkProcess-256:
# Process ForkProcess-376:
# Process ForkProcess-234:
# Process ForkProcess-344:
# Process ForkProcess-354:
# Process ForkProcess-161:
# Process ForkProcess-374:
# Process ForkProcess-396:
# Process ForkProcess-171:
# Process ForkProcess-393:
# Process ForkProcess-345:
# Process ForkProcess-73:
# Process ForkProcess-325:
# Process ForkProcess-175:
# Process ForkProcess-360:
# Process ForkProcess-373:
# Process ForkProcess-342:
# Process ForkProcess-349:
# Process ForkProcess-40:
# Process ForkProcess-269:
# Process ForkProcess-395:
# Process ForkProcess-89:
# Process ForkProcess-16:
# Process ForkProcess-267:
# Process ForkProcess-303:
# Process ForkProcess-109:
# Process ForkProcess-54:
# Process ForkProcess-381:
# Process ForkProcess-187:
# Process ForkProcess-189:
# Process ForkProcess-358:
# Process ForkProcess-104:
# Process ForkProcess-142:
# Process ForkProcess-164:
# Process ForkProcess-293:
# Process ForkProcess-108:
# Process ForkProcess-254:
# Process ForkProcess-362:
# Process ForkProcess-384:
# Process ForkProcess-347:
# Process ForkProcess-268:
# Process ForkProcess-357:
# Process ForkProcess-107:
# Process ForkProcess-368:
# Process ForkProcess-335:
# Process ForkProcess-182:
# Process ForkProcess-166:
# Process ForkProcess-288:
# Process ForkProcess-179:
# Process ForkProcess-377:
# Process ForkProcess-203:
# Process ForkProcess-370:
# Process ForkProcess-27:
# Process ForkProcess-185:
# Process ForkProcess-239:
# Process ForkProcess-351:
# Process ForkProcess-92:
# Process ForkProcess-308:
# Process ForkProcess-183:
# Process ForkProcess-341:
# Process ForkProcess-191:
# Process ForkProcess-159:
# Process ForkProcess-172:
# Process ForkProcess-193:
# Process ForkProcess-178:
# Process ForkProcess-366:
# Process ForkProcess-297:
# Process ForkProcess-174:
# Process ForkProcess-136:
# Process ForkProcess-223:
# Process ForkProcess-219:
# Process ForkProcess-188:
# Process ForkProcess-306:
# Process ForkProcess-224:
# Process ForkProcess-365:
# Process ForkProcess-162:
# Process ForkProcess-48:
# Process ForkProcess-194:
# Process ForkProcess-210:
# Process ForkProcess-168:
# Process ForkProcess-198:
# Process ForkProcess-42:
# Process ForkProcess-113:
# Process ForkProcess-226:
# Process ForkProcess-32:
# Process ForkProcess-378:
# Process ForkProcess-212:
# Process ForkProcess-386:
# Process ForkProcess-49:
# Process ForkProcess-291:
# Process ForkProcess-287:
# Process ForkProcess-214:
# Process ForkProcess-111:
# Process ForkProcess-397:
# Process ForkProcess-46:
# Process ForkProcess-123:
# Process ForkProcess-112:
# Process ForkProcess-371:
# Process ForkProcess-292:
# Process ForkProcess-229:
# Process ForkProcess-6:
# Process ForkProcess-55:
# Process ForkProcess-176:
# Process ForkProcess-259:
# Process ForkProcess-206:
# Process ForkProcess-87:
# Process ForkProcess-290:
# Process ForkProcess-8:
# Process ForkProcess-238:
# Process ForkProcess-15:
# Process ForkProcess-309:
# Process ForkProcess-82:
# Process ForkProcess-322:
# Process ForkProcess-314:
# Process ForkProcess-26:
# Process ForkProcess-273:
# Process ForkProcess-5:
# Process ForkProcess-7:
# Process ForkProcess-94:
# Process ForkProcess-332:
# Process ForkProcess-283:
# Process ForkProcess-154:
# Process ForkProcess-68:
# Process ForkProcess-266:
# Process ForkProcess-74:
# Process ForkProcess-81:
# Process ForkProcess-47:
# Process ForkProcess-126:
# Process ForkProcess-83:
# Process ForkProcess-98:
# Process ForkProcess-131:
# Process ForkProcess-1:
# Process ForkProcess-265:
# Process ForkProcess-117:
# Process ForkProcess-50:
# Process ForkProcess-165:
# Process ForkProcess-363:
# Process ForkProcess-114:
# Process ForkProcess-29:
# Process ForkProcess-149:
# Process ForkProcess-86:
# Process ForkProcess-337:
# Process ForkProcess-4:
# Process ForkProcess-257:
# Process ForkProcess-272:
# Process ForkProcess-232:
# Process ForkProcess-139:
# Process ForkProcess-281:
# Process ForkProcess-11:
# Process ForkProcess-141:
# Process ForkProcess-13:
# Process ForkProcess-12:
# Process ForkProcess-346:
# Process ForkProcess-110:
# Process ForkProcess-19:
# Process ForkProcess-280:
# Process ForkProcess-14:
# Process ForkProcess-80:
# Process ForkProcess-18:
# Process ForkProcess-67:
# Process ForkProcess-91:
# Process ForkProcess-34:
# Process ForkProcess-99:
# Process ForkProcess-279:
# Process ForkProcess-10:
# Process ForkProcess-270:
# Process ForkProcess-158:
# Process ForkProcess-261:
# Process ForkProcess-271:
# Process ForkProcess-45:
# Process ForkProcess-77:
# Process ForkProcess-85:
# Process ForkProcess-230:
# Process ForkProcess-163:
# Process ForkProcess-313:
# Process ForkProcess-316:
# Process ForkProcess-128:
# Process ForkProcess-231:
# Process ForkProcess-125:
# Process ForkProcess-133:
# Process ForkProcess-340:
# Process ForkProcess-275:
# Process ForkProcess-138:
# Process ForkProcess-211:
# Process ForkProcess-170:
# Process ForkProcess-196:
# Process ForkProcess-24:
# Process ForkProcess-23:
# Process ForkProcess-399:
# Process ForkProcess-44:
# Process ForkProcess-75:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/concurrent/futures/process.py", line 264, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/Othercomputers/Ο φορητός υπολογιστής μου/thesis_timeseries/src/experiments/corruption/run_ge_experiment.py", line 79, in process_single_job
#     df = pd.read_csv(filepath, header=None, names=['value', 'is_anomaly'])
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 626, in _read
#     return parser.read(nrows)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1923, in read
#     ) = self._engine.read(  # type: ignore[attr-defined]
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/c_parser_wrapper.py", line 234, in read
#     chunks = self._reader.read_low_memory(nrows)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "parsers.pyx", line 838, in pandas._libs.parsers.TextReader.read_low_memory
#   File "parsers.pyx", line 905, in pandas._libs.parsers.TextReader._read_rows
#   File "parsers.pyx", line 874, in pandas._libs.parsers.TextReader._tokenize_rows
#   File "parsers.pyx", line 891, in pandas._libs.parsers.TextReader._check_tokenize_status
#   File "parsers.pyx", line 2053, in pandas._libs.parsers.raise_parser_error
#   File "<frozen codecs>", line 319, in decode
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.12/concurrent/futures/process.py", line 266, in _process_worker
#     exc = _ExceptionWithTraceback(e, e.__traceback__)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/process.py", line 137, in __init__
#     tb = ''.join(format_exception(type(exc), exc, tb))
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 139, in format_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 733, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 438, in _extract_from_extended_frame_gen
#     f.line
#   File "/usr/lib/python3.12/traceback.py", line 323, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/linecache.py", line 141, in updatecache
#     with tokenize.open(fullname) as fp:
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/tokenize.py", line 459, in open
#     encoding, lines = detect_encoding(buffer.readline)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/tokenize.py", line 428, in detect_encoding
#     first = read_or_stop()
#             ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/tokenize.py", line 386, in read_or_stop
#     return readline()
#            ^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14348/2610419067.py in <cell line: 0>()
# ----> 1 get_ipython().system('python src/experiments/corruption/run_ge_experiment.py --workers 400')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     148       kwargs.update({'also_return_output': True})
#     149
# --> 150     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     151
#     152     if pip_warn:
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     456   )
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     202       os.close(child_pty)
#     203
# --> 204       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     205   finally:
#     206     epoll.close()
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_system_commands.py in _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     232   while True:
#     233     try:
# --> 234       result = _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     235       if result is not None:
#     236         return result
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_system_commands.py in _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     280   output_available = False
#     281
# --> 282   events = epoll.poll()
#     283   input_events = []
#     284   for _, event in events:
#
# KeyboardInterrupt:
